# %%
import pandas as pd

df = pd.read_excel("IEA_Hydrogen_Production_Projects_Database.xlsx", sheet_name="Projects", header=2)
# Out:
# C:\Users\abdss\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2442 entries, 0 to 2441
# Data columns (total 36 columns):
#  #   Column                                                                          Non-Null Count  Dtype
# ---  ------                                                                          --------------  -----
#  0   Unnamed: 0                                                                      2435 non-null   object
#  1   Unnamed: 1                                                                      2442 non-null   object
#  2   Unnamed: 2                                                                      2435 non-null   object
#  3   Unnamed: 3                                                                      1880 non-null   object
#  4   Unnamed: 4                                                                      115 non-null    object
#  5   Unnamed: 5                                                                      2433 non-null   object
# ...

# %%
df.head()
# Out:
#   Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 0        Ref                                       Project name    Country
# 1        NaN  Other projects from confidential sources (post...        NaN
# 2        NaN  Other projects from confidential sources (post...        NaN
# 3        NaN  Other projects from confidential sources (post...        NaN
# 4        NaN  Other projects from confidential sources (2000...        NaN
#
#     Unnamed: 3        Unnamed: 4   Unnamed: 5          Unnamed: 6  \
# 0  Date online  Decomission date       Status          Technology
# 1          NaN               NaN        Other           NG w CCUS
# 2          NaN               NaN        Other               Other
# 3          NaN               NaN        Other  Other Electrolysis
# 4          NaN               NaN  Operational                 PEM
#
#   Technology Comments Type of electricity (for electrolysis projects)  \
# ...

# %% [markdown]
# # Dropping data rows after isolating in other dfs(Other projects from confidential...)

# %%
df_other_projects = df.iloc[1:6]
df_non_energy_related_projects = df.iloc[6:8]

# %%
df_non_energy_related_projects.head()
# Out:
#   Unnamed: 0                               Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 6        NaN  Non-energy related projects (2000-2024)        NaN        NaN
# 7        NaN  Non-energy related projects (post-2024)        NaN        NaN
#
#   Unnamed: 4   Unnamed: 5 Unnamed: 6 Technology Comments  \
# 6        NaN  Operational  ALK & PEM                 NaN
# 7        NaN        Other        ALK                 NaN
#
#   Type of electricity (for electrolysis projects)  \
# 6                                             NaN
# 7                                             NaN
#
#   If dedicated renewables, type of renewable  ...       MWel Nm³ H₂/h kt H2/y  \
# 6                                        NaN  ...    78.3938      NaN     NaN
# 7                                        NaN  ...  46.556344      NaN     NaN
#
#   t CO₂ captured/y Unnamed: 30 Unnamed: 31  \
# 6              NaN           0         NaN
# 7              NaN           0         NaN
#
# ...

# %% [markdown]
# Resetting index and settings the columns names

# %%
df.columns = df.iloc[0]
df.drop(index=[0,1,2,3,4,5,6,7], axis=0, inplace=True)
df.reset_index(drop=True, inplace=True)
# Out:
# 0  Ref                             Project name Country Date online  \
# 8    3  H2GO Energy Park Oude-Tonge - 1st phase     NLD        2025
# 9    4  H2GO Energy Park Oude-Tonge - 2nd phase     NLD        2030
# 10   5                          NortH2, phase 1     NLD        2030
# 11   6                     Norsk e-Fuel Phase 1     NOR        2028
# 12   7                     Norsk e-Fuel Phase 2     NOR        2028
#
# 0  Decomission date             Status          Technology Technology_details  \
# 8               NaN   FID/Construction  Other Electrolysis        Unknown PtX
# 9               NaN            Concept  Other Electrolysis        Unknown PtX
# 10              NaN  Feasibility study  Other Electrolysis        Unknown PtX
# 11              NaN   FID/Construction                SOEC                NaN
# 12              NaN  Feasibility study                SOEC                NaN
#
# 0  Technology_electricity Technology_electricity_details  ... Capacity_MWel  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2434 entries, 0 to 2433
# Data columns (total 36 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Ref                                                          2434 non-null   object
#  1   Project name                                                 2434 non-null   object
#  2   Country                                                      2434 non-null   object
#  3   Date online                                                  1879 non-null   object
#  4   Decomission date                                             114 non-null    object
#  5   Status                                                       2425 non-null   object
#  6   Technology                                                   2433 non-null   object
# ...

# %% [markdown]
# Drop the reference column

# %%
df.drop(columns=["Ref"])
